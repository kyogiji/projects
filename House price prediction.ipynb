# %% [markdown]
# ### E22020-KARTHIK GH

# %% [markdown]
# ### E22031-SHRIYA MURALIDAS

# %% [markdown]
# ### E22036-YOGESH SINGH SHAKYA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv("House.csv")

# %%
df=df.drop(["sqft_living15","sqft_lot15"],axis = 1)
df
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 0     2487200875  20141209T000000   604000.0         4       3.00
# 1     7237550310  20140512T000000  1225000.0         4       4.50
# 2     9212900260  20140527T000000   468000.0         2       1.00
# 3      114101516  20140528T000000   310000.0         3       1.00
# 4     6054650070  20141007T000000   400000.0         3       1.75
# ...          ...              ...        ...       ...        ...
# 9756  9834201367  20150126T000000   429000.0         3       2.00
# 9757  3448900210  20141014T000000   610685.0         4       2.50
# 9758  7936000429  20150326T000000  1007500.0         4       3.50
# 9759  1523300141  20140623T000000   402101.0         2       0.75
# 9760  1523300157  20141015T000000   325000.0         2       0.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0            1960      5000     1.0           0     0          5      7
# 1            5420    101930     1.0           0     0          3     11
# 2            1160      6000     1.0           0     0          4      7
# 3            1430     19901     1.5           0     0          4      7
# 4            1370      9680     1.0           0     0          4      7
# ...           ...       ...     ...         ...   ...        ...    ...
# 9756         1490      1126     3.0           0     0          3      8
# 9757         2520      6023     2.0           0     0          3      9
# 9758         3510      7200     2.0           0     0          3      9
# 9759         1020      1350     2.0           0     0          3      7
# 9760         1020      1076     2.0           0     0          3      7
#
#       sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0           1050            910      1965             0    98136  47.5208
# 1           3890           1530      2001             0    98053  47.6561
# 2            860            300      1942             0    98115  47.6900
# 3           1430              0      1927             0    98028  47.7558
# 4           1370              0      1977             0    98074  47.6127
# ...          ...            ...       ...           ...      ...      ...
# 9756        1490              0      2014             0    98144  47.5699
# 9757        2520              0      2014             0    98056  47.5137
# 9758        2600            910      2009             0    98136  47.5537
# 9759        1020              0      2009             0    98144  47.5944
# 9760        1020              0      2008             0    98144  47.5941
#
#          long
# 0    -122.393
# 1    -122.005
# 2    -122.292
# 3    -122.229
# 4    -122.045
# ...       ...
# 9756 -122.288
# 9757 -122.167
# 9758 -122.398
# 9759 -122.299
# 9760 -122.299
#
# [9761 rows x 19 columns]

# %%
df.head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  2487200875  20141209T000000   604000.0         4       3.00         1960
# 1  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 2  9212900260  20140527T000000   468000.0         2       1.00         1160
# 3   114101516  20140528T000000   310000.0         3       1.00         1430
# 4  6054650070  20141007T000000   400000.0         3       1.75         1370
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5000     1.0           0     0          5      7        1050
# 1    101930     1.0           0     0          3     11        3890
# 2      6000     1.0           0     0          4      7         860
# 3     19901     1.5           0     0          4      7        1430
# 4      9680     1.0           0     0          4      7        1370
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long
# 0            910      1965             0    98136  47.5208 -122.393
# 1           1530      2001             0    98053  47.6561 -122.005
# 2            300      1942             0    98115  47.6900 -122.292
# 3              0      1927             0    98028  47.7558 -122.229
# 4              0      1977             0    98074  47.6127 -122.045

# %% [markdown]
# # QUESTIONS

# %% [markdown]
# 1.Newly built houses and with good condition will have higher price tag.
#
# 2.Houses with Views and waterfront will be costly.
#
# 3.houses with more sqft living ,bathroom and grade will be costly.
#
# 4.newly renovated house will also have decent price.

# %%
#no null values
print(pd.isnull(df).sum())
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# dtype: int64

# %%
df['price']=df['price'].astype("int64") #converts price into integer

# %%
df.describe()
# Out:
#                  id         price     bedrooms    bathrooms   sqft_living  \
# count  9.761000e+03  9.761000e+03  9761.000000  9761.000000   9761.000000
# mean   4.605288e+09  5.427350e+05     3.375884     2.117175   2086.734146
# std    2.876044e+09  3.795276e+05     0.960697     0.773971    927.194303
# min    1.200019e+06  8.000000e+04     0.000000     0.000000    290.000000
# 25%    2.126049e+09  3.200000e+05     3.000000     1.750000   1420.000000
# 50%    3.905041e+09  4.500000e+05     3.000000     2.250000   1910.000000
# 75%    7.338403e+09  6.490000e+05     4.000000     2.500000   2570.000000
# max    9.900000e+09  7.700000e+06    33.000000     8.000000  12050.000000
#
#            sqft_lot       floors   waterfront         view    condition  \
# count  9.761000e+03  9761.000000  9761.000000  9761.000000  9761.000000
# mean   1.521526e+04     1.486067     0.008401     0.248028     3.415531
# std    4.126673e+04     0.532317     0.091275     0.787877     0.650552
# min    5.200000e+02     1.000000     0.000000     0.000000     1.000000
# 25%    5.100000e+03     1.000000     0.000000     0.000000     3.000000
# 50%    7.642000e+03     1.500000     0.000000     0.000000     3.000000
# 75%    1.066000e+04     2.000000     0.000000     0.000000     4.000000
# max    1.651359e+06     3.500000     1.000000     4.000000     5.000000
#
#             grade   sqft_above  sqft_basement     yr_built  yr_renovated  \
# count  9761.00000  9761.000000    9761.000000  9761.000000   9761.000000
# mean      7.66151  1793.291159     293.442987  1970.799508     86.066592
# std       1.18268   835.763817     442.612722    29.240009    405.417369
# min       1.00000   290.000000       0.000000  1900.000000      0.000000
# 25%       7.00000  1190.000000       0.000000  1951.000000      0.000000
# 50%       7.00000  1570.000000       0.000000  1975.000000      0.000000
# 75%       8.00000  2230.000000     570.000000  1996.000000      0.000000
# max      13.00000  8860.000000    3480.000000  2015.000000   2015.000000
#
#             zipcode          lat         long
# count   9761.000000  9761.000000  9761.000000
# mean   98077.790185    47.560052  -122.214322
# std       53.203594     0.140236     0.139895
# min    98001.000000    47.155900  -122.514000
# 25%    98033.000000    47.467800  -122.327000
# 50%    98065.000000    47.572200  -122.229000
# 75%    98117.000000    47.680400  -122.126000
# max    98199.000000    47.777600  -121.319000

# %%
    df_nm_features = df.select_dtypes(exclude='object')  #this variable will have all the numerical variable
    df_ct_features = df.select_dtypes(include='object')  #this one will have all the categorical

# %%
df_nm_features
# Out:
#               id    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     2487200875   604000         4       3.00         1960      5000     1.0
# 1     7237550310  1225000         4       4.50         5420    101930     1.0
# 2     9212900260   468000         2       1.00         1160      6000     1.0
# 3      114101516   310000         3       1.00         1430     19901     1.5
# 4     6054650070   400000         3       1.75         1370      9680     1.0
# ...          ...      ...       ...        ...          ...       ...     ...
# 9756  9834201367   429000         3       2.00         1490      1126     3.0
# 9757  3448900210   610685         4       2.50         2520      6023     2.0
# 9758  7936000429  1007500         4       3.50         3510      7200     2.0
# 9759  1523300141   402101         2       0.75         1020      1350     2.0
# 9760  1523300157   325000         2       0.75         1020      1076     2.0
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0              0     0          5      7        1050            910      1965
# 1              0     0          3     11        3890           1530      2001
# 2              0     0          4      7         860            300      1942
# 3              0     0          4      7        1430              0      1927
# 4              0     0          4      7        1370              0      1977
# ...          ...   ...        ...    ...         ...            ...       ...
# 9756           0     0          3      8        1490              0      2014
# 9757           0     0          3      9        2520              0      2014
# 9758           0     0          3      9        2600            910      2009
# 9759           0     0          3      7        1020              0      2009
# 9760           0     0          3      7        1020              0      2008
#
#       yr_renovated  zipcode      lat     long
# 0                0    98136  47.5208 -122.393
# 1                0    98053  47.6561 -122.005
# 2                0    98115  47.6900 -122.292
# 3                0    98028  47.7558 -122.229
# 4                0    98074  47.6127 -122.045
# ...            ...      ...      ...      ...
# 9756             0    98144  47.5699 -122.288
# 9757             0    98056  47.5137 -122.167
# 9758             0    98136  47.5537 -122.398
# 9759             0    98144  47.5944 -122.299
# 9760             0    98144  47.5941 -122.299
#
# [9761 rows x 18 columns]

# %%
df_ct_features
# Out:
#                  date
# 0     20141209T000000
# 1     20140512T000000
# 2     20140527T000000
# 3     20140528T000000
# 4     20141007T000000
# ...               ...
# 9756  20150126T000000
# 9757  20141014T000000
# 9758  20150326T000000
# 9759  20140623T000000
# 9760  20141015T000000
#
# [9761 rows x 1 columns]

# %%
for i in df_nm_features:
    if len(df_nm_features[i].unique())>15:
        
        plt.hist(df_nm_features[i],color="orange",edgecolor="black") #making histogram of blue colour and black edge
        plt.xlabel(i)                         #labelling x axis
        plt.ylabel('Frequency ')
        plt.title('Histogram of attribute '+i,fontsize=11)
        plt.show()

# %%
for i in df_nm_features:
    if len(df_nm_features[i].unique())>15:
          
        sns.boxplot(x=df_nm_features[i],color='red') #making boxplot of blue colour
        plt.xlabel(i,fontsize=11)
        plt.title('Boxplot of attribute '+i,fontsize=11) # string concatenation in naming
        plt.show()

# %%
for i in df_nm_features:
        if len(df_nm_features[i].unique())<15:
            df_nm_features[i].value_counts().plot(kind='bar',figsize=(5,5),
                                                       color="pink",fontsize=11)
            plt.xlabel(i)
            plt.ylabel("Frequency"+ " "+ i)
            plt.title('Bar graph of attribute  '+i,fontsize=11)
            plt.show()

# %% [markdown]
# 1.most house are in decent condition, more than 60% have condition 3 on scle of 5
#
# 2.90%house have 0 views.
#
# 3.house with waterfront are few.

# %% [markdown]
# # Bivariate Analysis

# %%
df_num=df[["price","bedrooms","bathrooms","sqft_living","floors","view","grade","sqft_above","sqft_basement"]]
plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title("House pricing Heatmap")
corr = df_num.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, cmap="Blues",linewidths=.5)
# Out:
# <AxesSubplot:title={'center':'House pricing Heatmap'}>

# %%
corr=df.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_f9b78_row0_col0, #T_f9b78_row1_col1, #T_f9b78_row2_col2, #T_f9b78_row3_col3, #T_f9b78_row4_col4, #T_f9b78_row5_col5, #T_f9b78_row6_col6, #T_f9b78_row7_col7, #T_f9b78_row8_col8, #T_f9b78_row9_col9, #T_f9b78_row10_col10, #T_f9b78_row11_col11, #T_f9b78_row12_col12, #T_f9b78_row13_col13, #T_f9b78_row14_col14, #T_f9b78_row15_col15, #T_f9b78_row16_col16, #T_f9b78_row17_col17 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f9b78_row0_col1, #T_f9b78_row9_col10 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_f9b78_row0_col2, #T_f9b78_row2_col16, #T_f9b78_row7_col16, #T_f9b78_row9_col8, #T_f9b78_row10_col0, #T_f9b78_row17_col14 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_f9b78_row0_col3, #T_f9b78_row6_col16, #T_f9b78_row12_col11 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_f9b78_row0_col4, #T_f9b78_row5_col8, #T_f9b78_row9_col2, #T_f9b78_row13_col5 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_f9b78_row0_col5, #T_f9b78_row5_col0, #T_f9b78_row6_col12, #T_f9b78_row9_col6, #T_f9b78_row9_col13, #T_f9b78_row13_col9, #T_f9b78_row13_col14, #T_f9b78_row13_col16, #T_f9b78_row15_col1, #T_f9b78_row15_col2, #T_f9b78_row15_col3, #T_f9b78_row15_col4, #T_f9b78_row15_col5, #T_f9b78_row15_col10, #T_f9b78_row15_col11, #T_f9b78_row15_col13, #T_f9b78_row15_col17, #T_f9b78_row17_col7, #T_f9b78_row17_col8, #T_f9b78_row17_col15 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f9b78_row0_col6, #T_f9b78_row10_col5 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_f9b78_row0_col7 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_f9b78_row0_col8, #T_f9b78_row13_col12, #T_f9b78_row14_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_f9b78_row0_col9, #T_f9b78_row7_col4, #T_f9b78_row15_col12, #T_f9b78_row16_col9 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_f9b78_row0_col10, #T_f9b78_row14_col8, #T_f9b78_row14_col10 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_f9b78_row0_col11, #T_f9b78_row5_col6, #T_f9b78_row14_col3, #T_f9b78_row14_col4 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_f9b78_row0_col12, #T_f9b78_row5_col12 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_f9b78_row0_col13, #T_f9b78_row1_col14, #T_f9b78_row16_col12 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_f9b78_row0_col14, #T_f9b78_row10_col9, #T_f9b78_row12_col13, #T_f9b78_row14_col1, #T_f9b78_row14_col16 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_f9b78_row0_col15, #T_f9b78_row9_col12, #T_f9b78_row17_col3 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_f9b78_row0_col16, #T_f9b78_row2_col5, #T_f9b78_row2_col8, #T_f9b78_row5_col1, #T_f9b78_row7_col5, #T_f9b78_row8_col16, #T_f9b78_row9_col14 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_f9b78_row0_col17 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_f9b78_row1_col0, #T_f9b78_row2_col0, #T_f9b78_row6_col5, #T_f9b78_row11_col0, #T_f9b78_row12_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_f9b78_row1_col2, #T_f9b78_row12_col2 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_f9b78_row1_col3, #T_f9b78_row3_col6 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_f9b78_row1_col4, #T_f9b78_row3_col11 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_f9b78_row1_col5, #T_f9b78_row6_col14, #T_f9b78_row8_col2, #T_f9b78_row10_col14, #T_f9b78_row11_col14 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_f9b78_row1_col6 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_f9b78_row1_col7, #T_f9b78_row1_col13, #T_f9b78_row5_col4, #T_f9b78_row5_col13, #T_f9b78_row6_col1, #T_f9b78_row12_col10 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_f9b78_row1_col8, #T_f9b78_row2_col12 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_f9b78_row1_col9 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_f9b78_row1_col10, #T_f9b78_row10_col3 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_f9b78_row1_col11 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_f9b78_row1_col12 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_f9b78_row1_col15 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_f9b78_row1_col16 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_f9b78_row1_col17, #T_f9b78_row7_col15 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_f9b78_row2_col1, #T_f9b78_row16_col1 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_f9b78_row2_col3 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_f9b78_row2_col4 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_f9b78_row2_col6, #T_f9b78_row5_col11 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_f9b78_row2_col7, #T_f9b78_row16_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_f9b78_row2_col9, #T_f9b78_row9_col17 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_f9b78_row2_col10, #T_f9b78_row6_col17 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_f9b78_row2_col11, #T_f9b78_row10_col6, #T_f9b78_row11_col13 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_f9b78_row2_col13, #T_f9b78_row8_col10 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_f9b78_row2_col14, #T_f9b78_row8_col5 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_f9b78_row2_col15, #T_f9b78_row13_col2 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_f9b78_row2_col17, #T_f9b78_row13_col4 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_f9b78_row3_col0, #T_f9b78_row9_col16, #T_f9b78_row16_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_f9b78_row3_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_f9b78_row3_col2 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_f9b78_row3_col4, #T_f9b78_row4_col3 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_f9b78_row3_col5, #T_f9b78_row5_col14, #T_f9b78_row17_col9 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_f9b78_row3_col7, #T_f9b78_row9_col1, #T_f9b78_row14_col13 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_f9b78_row3_col8, #T_f9b78_row10_col15, #T_f9b78_row15_col14 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_f9b78_row3_col9 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_f9b78_row3_col10 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_f9b78_row3_col12, #T_f9b78_row8_col12 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_f9b78_row3_col13, #T_f9b78_row6_col11, #T_f9b78_row11_col1, #T_f9b78_row11_col6 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_f9b78_row3_col14, #T_f9b78_row4_col14, #T_f9b78_row7_col3, #T_f9b78_row8_col13, #T_f9b78_row14_col6, #T_f9b78_row14_col9, #T_f9b78_row14_col11 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_f9b78_row3_col15, #T_f9b78_row4_col9, #T_f9b78_row4_col15, #T_f9b78_row7_col6, #T_f9b78_row10_col16, #T_f9b78_row11_col8 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_f9b78_row3_col16, #T_f9b78_row11_col9, #T_f9b78_row14_col2, #T_f9b78_row16_col13, #T_f9b78_row17_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_f9b78_row3_col17, #T_f9b78_row4_col6 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_f9b78_row4_col0, #T_f9b78_row9_col5 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_f9b78_row4_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_f9b78_row4_col2, #T_f9b78_row6_col13 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_f9b78_row4_col5, #T_f9b78_row7_col11, #T_f9b78_row7_col12 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_f9b78_row4_col7, #T_f9b78_row9_col4, #T_f9b78_row13_col15 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_f9b78_row4_col8, #T_f9b78_row7_col17, #T_f9b78_row10_col12 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_f9b78_row4_col10, #T_f9b78_row10_col4 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_f9b78_row4_col11 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_f9b78_row4_col12, #T_f9b78_row6_col10, #T_f9b78_row13_col11 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_f9b78_row4_col13, #T_f9b78_row5_col17 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_f9b78_row4_col16,

# %% [markdown]
#    We see that sqft living , bathrooms, grade and sqft above have corr>.5 wrt price
#    so we plot scatter plot between them

# %%
df.plot(kind="scatter",                                    
                        x="sqft_living",y="price",                                 
                        color='orange',                                      
                        figsize=(5,5)) 
plt.ylabel("price", fontsize=12)
plt.xlabel("sqft_living",fontsize =12)
plt.title("scatterplot", fontsize=16)
plt.show()

# %%
col=["sqft_above","sqft_living","bathrooms","grade"]

for i in col:
    df.plot(kind="scatter",                                    
                        x=i,y="price",                                 
                        color='red',                                      
                        figsize=(5,5)) 
    plt.ylabel("price", fontsize=12)
    plt.xlabel(i,fontsize =12)
    plt.title("scatterplot", fontsize=16)
    plt.show()

# %%
col=["waterfront","view","condition","bathrooms","grade"]     #list of features for plotting boxplots

for i in col:
    df.boxplot(column="price",notch=True,
            by=i,
            grid=False,
            figsize=(6,5))

    plt.ylabel("Price", fontsize=12)


    plt.show()

# %% [markdown]
# # 2.

# %% [markdown]
# OBS 1:as the sqft living increases , the price of house increses,positive trend
#
# OBS 2: Sqft_above also show positive similar to sqft_living.
#
# OBS 3:as grade of house increse price also increase.
#
# OBS 4: as no of bathrooms increse price increses.
#
# OBS  5: houses with waterfront are costlier than houses without them.
#
# OBS 6 :condition affected the price but not much                                       {SURPRISING}
#
# OBS 7: AGE of house didn't affected price much(done below in CREATING NEW FEATURE .)   {SURPRISING}
#
# lot of outliers in all boxplots, means other features also determine price.

# %% [markdown]
# ## 3 Decision Tree

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#For test-train split
from sklearn.model_selection import train_test_split

#For fitting regression tree
from sklearn.tree import DecisionTreeRegressor

#To create a confusion matrix
from sklearn.metrics import confusion_matrix

#For plotting a decision tree
from sklearn import tree

# %% [markdown]
# ### First SET of PREDICTORS

# %% [markdown]
# Took these FEATURES as they showed a TREND with price
#
# FIRST SET  [["sqft_living","bathrooms","grade"]]
#
# SECOND SET [["sqft_living","bedrooms","bathrooms","view","grade","floors","condition","waterfront"]]

# %%
X = df[["sqft_living","bathrooms","grade"]]   
y = df.price

# %%
#STANDARDIZATION

# %%
X_scaled = X.apply(lambda x: (x - np.mean(x)) / np.std(x))

# %%
X_scaled                     #scale
# Out:
#       sqft_living  bathrooms     grade
# 0       -0.136693   1.140701 -0.559360
# 1        3.595187   3.078858  2.822962
# 2       -0.999555  -1.443507 -0.559360
# 3       -0.708339  -1.443507 -0.559360
# 4       -0.773054  -0.474429 -0.559360
# ...           ...        ...       ...
# 9756    -0.643624  -0.151403  0.286220
# 9757     0.467311   0.494649  1.131801
# 9758     1.535103   1.786754  1.131801
# 9759    -1.150556  -1.766533 -0.559360
# 9760    -1.150556  -1.766533 -0.559360
#
# [9761 rows x 3 columns]

# %%
X_scaled.var()
# Out:
# sqft_living    1.000102
# bathrooms      1.000102
# grade          1.000102
# dtype: float64

# %%
#Train-Validation Split
X_train, X_valid, y_train, y_valid = train_test_split(X_scaled, y, test_size = .3)

# %%
#fitting decision tree
reg_tree = DecisionTreeRegressor(max_depth=8, min_samples_leaf=5) #greedy algorithm
reg_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=5)

# %%
fig, axes = plt.subplots(figsize=(3,3), dpi=300)

tree.plot_tree(reg_tree, feature_names=list(X), filled = False)

plt.show()

# %%
y_pred = reg_tree.predict(X_valid)
y_pred
# Out:
# array([607311.1634981 , 492565.10982659, 443286.98387097, ...,
#        952706.25954198, 356985.15878378, 430142.85714286])

# %%
# RMSE
np.sqrt(np.mean((y_valid - y_pred)**2))
# Out:
# 239925.26775987796

# %%
# MAE
np.mean(np.abs(y_valid - y_pred))
# Out:
# 154637.56965312874

# %%
# MAPE
np.mean(np.abs(y_valid - y_pred)/y_valid)*100
# Out:
# 32.15851008815165

# %%
from sklearn.metrics import r2_score       #r2 score
score=r2_score(y_valid,y_pred)
score
# Out:
# 0.5666056727611195

# %% [markdown]
# ### ANOTHER SET OF PREDICTORS

# %% [markdown]
# SET 1 PREDICTORS GAVE 32% ERROR i.e model didn't perform well with those features.
#
# SET 2 kept the set 1 included in set 2 because togehther with other predictors they might give good results.

# %%
X = df[["sqft_living","bedrooms","bathrooms","view","grade","floors","condition","waterfront"]] 
y = df.price

# %%
X_scaled = X.apply(lambda x: (x - np.mean(x)) / np.std(x))
#Train-Validation Split
X_train, X_valid, y_train, y_valid = train_test_split(X_scaled, y, test_size = .3)
#fitting decision tree
reg_tree = DecisionTreeRegressor(max_depth=8, min_samples_leaf=5) #greedy algorithm
reg_tree.fit(X_train, y_train)

fig, axes = plt.subplots(figsize=(3,3), dpi=300)

tree.plot_tree(reg_tree, feature_names=list(X), filled = False)

plt.show()

# %%
y_pred = reg_tree.predict(X_valid)
y_pred
# Out:
# array([ 818911.18987342,  409071.68224299,  509659.12151899, ...,
#         414183.73800738, 1061666.66666667,  713144.67741935])

# %%
# MAPE
np.mean(np.abs(y_valid - y_pred)/y_valid)*100
# Out:
# 30.568574564044116

# %%
# MAE
np.mean(np.abs(y_valid - y_pred))
# Out:
# 149703.619819718

# %%
# RMSE
np.sqrt(np.mean((y_valid - y_pred)**2))
# Out:
# 239164.23925567121

# %%
score=r2_score(y_valid,y_pred)
score
# Out:
# 0.6092266083529592

# %% [markdown]
# Comparision OF SET1 AND SET2
#
#
# MAPE (Error) reduced from 31 to 28.6 with second set of predictors, which is good.
#
# r2 score incresed from .56 to .62, which means its a better fit.

# %% [markdown]
# # 4 feature engineering

# %% [markdown]
# #ERROR IS VERY HIGH,so taking log transformation of target -->price

# %%
df['log_price'] = np.log(df['price'])  #log transform ation of price

# %%
df
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 0     2487200875  20141209T000000   604000         4       3.00         1960
# 1     7237550310  20140512T000000  1225000         4       4.50         5420
# 2     9212900260  20140527T000000   468000         2       1.00         1160
# 3      114101516  20140528T000000   310000         3       1.00         1430
# 4     6054650070  20141007T000000   400000         3       1.75         1370
# ...          ...              ...      ...       ...        ...          ...
# 9756  9834201367  20150126T000000   429000         3       2.00         1490
# 9757  3448900210  20141014T000000   610685         4       2.50         2520
# 9758  7936000429  20150326T000000  1007500         4       3.50         3510
# 9759  1523300141  20140623T000000   402101         2       0.75         1020
# 9760  1523300157  20141015T000000   325000         2       0.75         1020
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0         5000     1.0           0     0          5      7        1050
# 1       101930     1.0           0     0          3     11        3890
# 2         6000     1.0           0     0          4      7         860
# 3        19901     1.5           0     0          4      7        1430
# 4         9680     1.0           0     0          4      7        1370
# ...        ...     ...         ...   ...        ...    ...         ...
# 9756      1126     3.0           0     0          3      8        1490
# 9757      6023     2.0           0     0          3      9        2520
# 9758      7200     2.0           0     0          3      9        2600
# 9759      1350     2.0           0     0          3      7        1020
# 9760      1076     2.0           0     0          3      7        1020
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0               910      1965             0    98136  47.5208 -122.393
# 1              1530      2001             0    98053  47.6561 -122.005
# 2               300      1942             0    98115  47.6900 -122.292
# 3                 0      1927             0    98028  47.7558 -122.229
# 4                 0      1977             0    98074  47.6127 -122.045
# ...             ...       ...           ...      ...      ...      ...
# 9756              0      2014             0    98144  47.5699 -122.288
# 9757              0      2014             0    98056  47.5137 -122.167
# 9758            910      2009             0    98136  47.5537 -122.398
# 9759              0      2009             0    98144  47.5944 -122.299
# 9760              0      2008             0    98144  47.5941 -122.299
#
#       log_price
# 0     13.311329
# 1     14.018451
# 2     13.056224
# 3     12.644328
# 4     12.899220
# ...         ...
# 9756  12.969212
# 9757  13.322337
# 9758  13.822983
# 9759  12.904459
# 9760  12.691580
#
# [9761 rows x 20 columns]

# %%
plt.hist(df["log_price"],color="orange",edgecolor="black") 
plt.xlabel("log_price")                         
plt.ylabel('Frequency ')
plt.title('Histogram of attribute '+i,fontsize=11)
plt.show()

# %% [markdown]
#  *  now the price becomes more normally distributed

# %%
#taking log transform of target
X = df[["sqft_living","bedrooms","bathrooms","view","grade","floors","condition","waterfront"]] 
y = df.log_price

# %%
X_scaled = X.apply(lambda x: (x - np.mean(x)) / np.std(x))    #standardization
#Train-Validation Split
X_train, X_valid, y_train, y_valid = train_test_split(X_scaled, y, test_size = .3)


#fitting decision tree
reg_tree = DecisionTreeRegressor(max_depth=8, min_samples_leaf=5) #greedy algorithm
reg_tree.fit(X_train, y_train)


fig, axes = plt.subplots(figsize=(3,3), dpi=300)

tree.plot_tree(reg_tree, feature_names=list(X), filled = False)

plt.show()

y_pred = reg_tree.predict(X_valid)
y_pred
# Out:
# array([13.26063859, 12.55744194, 13.2576012 , ..., 12.91131028,
#        13.63850009, 12.96010825])

# %%
# MAPE
np.mean(np.abs(y_valid - y_pred)/y_valid)*100
# Out:
# 2.0596970922368643

# %%
# RMSE
np.sqrt(np.mean((y_valid - y_pred)**2))
# Out:
# 0.33627488115998233

# %%
from sklearn.metrics import r2_score
score=r2_score(y_valid,y_pred)
score
# Out:
# 0.5792540381369865

# %%
#MAPE after taking antilog of y_valid and Y_pred
np.mean(np.abs(np.exp(y_valid)-np.exp(y_pred))/np.exp(y_valid))*100
# Out:
# 27.496116451890778

# %% [markdown]
# ERROR REDUCED BUT NOT MUCH SO CREATING NEW FEATURE AGE

# %% [markdown]
# ### CREATING NEW FEATURE

# %%
#AGE OF HOUSE

# %%
df.date=pd.to_datetime(df["date"])

# %%
df['year'] = pd. DatetimeIndex(df['date']). year
df['Age']= df['year']-df['yr_built']

# %%
df.Age.describe()
# Out:
# count    9761.000000
# mean       43.516750
# std        29.239324
# min        -1.000000
# 25%        18.000000
# 50%        40.000000
# 75%        63.000000
# max       115.000000
# Name: Age, dtype: float64

# %%
df.plot(kind="scatter",                           #making scatter plot of age and price to see their relation 
                        x="price",y="Age",                                 
                        color='orange',                                      
                        figsize=(5,5)) 
plt.ylabel("Age", fontsize=12)
plt.xlabel("price",fontsize =12)
plt.title("scatterplot", fontsize=16)
plt.show()

# %%
import seaborn as sns            #plotting trivariate scatter plot of price , age and grade  as bivariate plot didn't show any pattern
(sns
 .FacetGrid(df, hue='grade', size=5)
 .map(plt.scatter, 'Age', 'price')
 .add_legend()
 .set(
    title='age vs price wrt grade',
    xlabel='Age',
    ylabel='price'
 ));
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# higher grade house are built within 30 years
#
# intial thought that age will affect price but after bivariate scatter plot was inconclusive
#
# but trivariate shows that with grade and age ,there seems a  relation.

# %%
import seaborn as sns        #plotting trivariate scatter plot of price , age and condition  as bivariate plot didn't show any pattern
(sns
 .FacetGrid(df, hue='condition', size=5)
 .map(plt.scatter, 'Age', 'price')
 .add_legend()
 .set(
    title='age vs price wrt grade',
    xlabel='Age',
    ylabel='price'
 ));

# %% [markdown]
# new houses seem to have mediocre condition
#
# houses older than 20 are kept in good condition

# %%
#changing yr_renovated in boolean.
df['renovation']=df["yr_renovated"].apply(lambda x:1 if x>0 else 0)

# %%
#converting  some predictors to exponential then seeing the difference (as their values were small)
def expn (l):
    for i in l:
        df["exp_"+i]=np.exp(df[i])

# %%
l=["bathrooms","grade"]           #exponential transformation of bathrooms and grade
expn(l)

# %%
df['bedrooms_exponential']=np.exp(df.bedrooms)  #exponential transform of bedrooms  
df['sqft_living_log']=np.log(df['sqft_living'])  #log transform of sqft_living

# %%
df
# Out:
#               id       date    price  bedrooms  bathrooms  sqft_living  \
# 0     2487200875 2014-12-09   604000         4       3.00         1960
# 1     7237550310 2014-05-12  1225000         4       4.50         5420
# 2     9212900260 2014-05-27   468000         2       1.00         1160
# 3      114101516 2014-05-28   310000         3       1.00         1430
# 4     6054650070 2014-10-07   400000         3       1.75         1370
# ...          ...        ...      ...       ...        ...          ...
# 9756  9834201367 2015-01-26   429000         3       2.00         1490
# 9757  3448900210 2014-10-14   610685         4       2.50         2520
# 9758  7936000429 2015-03-26  1007500         4       3.50         3510
# 9759  1523300141 2014-06-23   402101         2       0.75         1020
# 9760  1523300157 2014-10-15   325000         2       0.75         1020
#
#       sqft_lot  floors  waterfront  view  ...      lat     long  log_price  \
# 0         5000     1.0           0     0  ...  47.5208 -122.393  13.311329
# 1       101930     1.0           0     0  ...  47.6561 -122.005  14.018451
# 2         6000     1.0           0     0  ...  47.6900 -122.292  13.056224
# 3        19901     1.5           0     0  ...  47.7558 -122.229  12.644328
# 4         9680     1.0           0     0  ...  47.6127 -122.045  12.899220
# ...        ...     ...         ...   ...  ...      ...      ...        ...
# 9756      1126     3.0           0     0  ...  47.5699 -122.288  12.969212
# 9757      6023     2.0           0     0  ...  47.5137 -122.167  13.322337
# 9758      7200     2.0           0     0  ...  47.5537 -122.398  13.822983
# 9759      1350     2.0           0     0  ...  47.5944 -122.299  12.904459
# 9760      1076     2.0           0     0  ...  47.5941 -122.299  12.691580
#
#       year  Age  renovation  exp_bathrooms     exp_grade  \
# 0     2014   49           0      20.085537   1096.633158
# 1     2014   13           0      90.017131  59874.141715
# 2     2014   72           0       2.718282   1096.633158
# 3     2014   87           0       2.718282   1096.633158
# 4     2014   37           0       5.754603   1096.633158
# ...    ...  ...         ...            ...           ...
# 9756  2015    1           0       7.389056   2980.957987
# 9757  2014    0           0      12.182494   8103.083928
# 9758  2015    6           0      33.115452   8103.083928
# 9759  2014    5           0       2.117000   1096.633158
# 9760  2014    6           0       2.117000   1096.633158
#
#       bedrooms_exponential  sqft_living_log
# 0                54.598150         7.580700
# 1                54.598150         8.597851
# 2                 7.389056         7.056175
# 3                20.085537         7.265430
# 4                20.085537         7.222566
# ...                    ...              ...
# 9756             20.085537         7.306531
# 9757             54.598150         7.832014
# 9758             54.598150         8.163371
# 9759              7.389056         6.927558
# 9760              7.389056         6.927558
#
# [9761 rows x 27 columns]

# %% [markdown]
# featured engg
#
# 1.log transform of price as it was rightly skewed intially,after transformation it was normally distributed
#
# 2.Yr_renovated converted into boolean 0and 1
#
# 3.created new feature AGE, did its analysis with price(above)
#
# 4.Exponential transformation of bedroom and bathroom.
#
# 5.log transform of sqft_living

# %% [markdown]
# # 5)	Model fitting step 2

# %%
#Using the transformed features and new features created 
X = df[['sqft_living_log',"exp_bathrooms","exp_grade","waterfront","view","Age",'renovation','bedrooms_exponential']]
y = df.log_price

# %%
X_scaled = X.apply(lambda x: (x - np.mean(x)) / np.std(x))


#Train-Validation Split
X_train, X_valid, y_train, y_valid = train_test_split(X_scaled, y, test_size = .3)

# %%
#fitting decision tree
reg_tree = DecisionTreeRegressor(max_depth=7, min_samples_leaf=5) #greedy algorithm
reg_tree.fit(X_train, y_train)


fig, axes = plt.subplots(figsize=(3,3), dpi=300)

tree.plot_tree(reg_tree, feature_names=list(X), filled = False)

plt.show()

y_pred = reg_tree.predict(X_valid)
y_pred
# Out:
# array([12.98650628, 12.87781561, 13.65875839, ..., 12.70430028,
#        12.82107551, 13.19299582])

# %%
# MAPE
np.mean(np.abs(y_valid - y_pred)/y_valid)*100
# Out:
# 1.9642248534201747

# %%
# RMSE
np.sqrt(np.mean((y_valid - y_pred)**2))
# Out:
# 0.3234169978936501

# %%
#MAPE after taking antilog of y_valid and Y_pred
np.mean(np.abs(np.exp(y_valid)-np.exp(y_pred))/np.exp(y_valid))*100
# Out:
# 26.842045944334725

# %% [markdown]
# Error reduced from 28.6 to 26.4 after feature engineering

# %% [markdown]
# ### Hyperparameter Tuning - Choosing Best Depth

# %%
# Hyperparameter Tuning - Choosing Best Depth
depth = np.arange(1,15)
mae = []

for k in depth:
    reg_tree = DecisionTreeRegressor(max_depth=k, min_samples_leaf=5)
    reg_tree.fit(X_train, y_train)
    y_pred = reg_tree.predict(X_valid)
    mae.append(np.mean(np.abs(y_valid - y_pred))) #MAD

# %%
plt.plot(depth, np.array(mae))
plt.show()

# %% [markdown]
# k=7

# %% [markdown]
# # 6)	Model testing

# %%
df11 = pd.read_csv("house_test.csv")

# %% [markdown]
# DOING ALL THE CHANGES ON THE TEST DATASET AND APPLYING THE BEST DECISION TREE REGRESSOR WITH BEST DEPTH=7

# %%
df11=df11.drop(["sqft_living15","sqft_lot15"],axis = 1)
df11

df11['log_price'] = np.log(df11['price'])

df11['price_per_sqft']=df11['price']/df11['sqft_lot']

df11.date=pd.to_datetime(df11["date"])

df11['year'] = pd. DatetimeIndex(df11['date']). year
df11['Age']= df11['year']-df11['yr_built']

#changing yr_renovated in boolean.
df11['renovation']=df11["yr_renovated"].apply(lambda x:1 if x>0 else 0)

#converting predictors to exponential then seeing the difference
def expn (l):
    for i in l:
        df11["exp_"+i]=np.exp(df11[i])

l=["bathrooms","grade"]
expn(l)

df11['bedrooms_exponential']=np.exp(df11.bedrooms)
df11['sqft_living_log']=np.log(df11['sqft_living'])



X_test = df[['sqft_living_log',"exp_bathrooms","exp_grade","waterfront","view","Age",'renovation','bedrooms_exponential']]
y_test = df.log_price

X_scaled1 = X_test.apply(lambda x: (x - np.mean(x)) / np.std(x))

reg_tree = DecisionTreeRegressor(max_depth=7, min_samples_leaf=5) #greedy algorithm
reg_tree.fit(X_scaled, y)


fig, axes = plt.subplots(figsize=(3,3), dpi=300)

tree.plot_tree(reg_tree, feature_names=list(X), filled = False)

plt.show()

y_pred1 = reg_tree.predict(X_scaled1)
y_pred1

#MAPE after taking antilog of y_valid and Y_pred
print(np.mean(np.abs(np.exp(y_test)-np.exp(y_pred1))/np.exp(y_test))*100)
# Out:
# 24.722427648202327

# %% [markdown]
# FINAL ERROR =24.72
#
# ACCURACY=75.28

# %% [markdown]
# RESULTS:
#
# INITAL ERROR FROM THE SET 1 WAS 32%, CAME DOWN TILL 26.4 AFTER HYPERPARAMETER TUNING.
#
# AFTER APPLYING THE BEST DEPTH WITH BEST FEATURES THE TEST DATA GAVE ERROR 24.72%

# %%
### Linear Regression

#Linear Regression
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_scaled, y)



# MSE (Mean Squared Error)
#MSE_rf=np.mean((y_test - y_pred)**2)
#MSE_rf

#MAPE 
#print(np.mean(np.abs(y_test-y_pred)/y_test)*100)

# %%
reg.score(X_scaled, y)
# Out:
# 0.5498541109612031

# %%
y_pred1=reg.predict(X_scaled1)

# %%
#MAPE after taking antilog of y_valid and Y_pred
print(np.mean(np.abs(np.exp(y_test)-np.exp(y_pred1))/np.exp(y_test))*100)
# Out:
# 30.308209551324722
